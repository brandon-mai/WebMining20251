# %%
# !git clone https://github.com/brandon-mai/subgraph-sketching.git
# Out:
# Cloning into 'subgraph-sketching'...
# remote: Enumerating objects: 672, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 672 (delta 230), reused 210 (delta 207), pack-reused 412 (from 1)
# Receiving objects: 100% (672/672), 176.39 KiB | 16.04 MiB/s, done.
# Resolving deltas: 100% (398/398), done.

# %%
import importlib, sys, types

# Create a fake imp module with reload pointing to importlib.reload
imp = types.ModuleType("imp")
imp.reload = importlib.reload
sys.modules["imp"] = imp
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install "torch==2.2.2+cu121" --index-url https://download.pytorch.org/whl/cu121 -q

# # 2) Cài PyG core
# %pip install "torch-geometric==2.4.0" -q

# # 3) Cài các extension của PyG cho đúng bản torch 2.2.2 + cu121
# %pip install pyg_lib torch-scatter torch-sparse torch-cluster torch-spline-conv \
#   -f https://data.pyg.org/whl/torch-2.2.2+cu121.html -q

# # 4) (tuỳ chọn) GUDHI
# %pip install gudhi ogb wandb datasketch numpy==1.26.4 -q

import sys

# !uv pip install --system --quiet \
  "torch==2.2.2+cu121" \
  --index-url https://download.pytorch.org/whl/cu121

# !uv pip install --system --quiet \
  "torch-geometric==2.4.0" \
  gudhi ogb wandb datasketch "numpy==1.26.4"

# !uv pip install --system --quiet \
  pyg_lib torch-scatter torch-sparse torch-cluster torch-spline-conv \
  --find-links https://data.pyg.org/whl/torch-2.2.2+cu121.html
# Out:
# [autoreload of numpy failed: Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py", line 410, in superreload
#     update_generic(old_obj, new_obj)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py", line 347, in update_generic
#     update(a, b)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py", line 317, in update_class
#     update_instances(old, new)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/extensions/autoreload.py", line 280, in update_instances
#     ref.__class__ = new
#     ^^^^^^^^^^^^^
# TypeError: __class__ assignment: 'errstate' object layout differs from 'errstate'
# ]
# [autoreload of numpy.ma.core failed: Traceback (most recent call last):
# ...

# %%
# %cd subgraph-sketching/src
# Out:
# /content/subgraph-sketching/src

# %%
import os
os.environ["WANDB_API_KEY"]=''
os.environ["HF_TOKEN"]=''
os.environ["HF_REPO_ID"]=''
os.environ["WANDB_ENTITY"] = ""
os.environ["WANDB_PROJECT"] = ""

import wandb
# !wandb login $WANDB_API_KEY
# Out:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
# !python runners/run.py \
  --dataset ogbl-collab --K 50 --model ELPH \
  --use_feature 0 --train_node_embedding --propagate_embeddings \
  --epochs 2 \
  --batch_size 131072 \
  --hidden_channels 256 \
  --label_dropout 0.25 \
  --lr 0.0005 \
  --num_negs 6 \
  --sign_k 2 \
  --wandb --wandb_project $WANDB_PROJECT --wandb_entity $WANDB_ENTITY \
  --hf_repo_id $HF_REPO_ID --hf_token $HF_TOKEN \
  --wandb_run_name collab-baseline-pull \
  --use_pull
# Out:
# /content/subgraph-sketching/src/../src/hashing.py:261: SyntaxWarning: invalid escape sequence '\s'
#   of path distances from the source and destination nodes. There are k+2+\sum_1^k 2k features
# ...
